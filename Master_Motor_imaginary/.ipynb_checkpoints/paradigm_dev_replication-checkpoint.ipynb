# %%
from psychopy import visual, core, event #import some libraries from PsychoPy

#create a window - depend on computers in lab 
mywin = visual.Window([800,600],monitor="testMonitor", units="deg")

# stimuli generation
grating = visual.GratingStim(win=mywin, mask='circle', size=3, pos=[-4,0], sf=3)
fixation = visual.GratingStim(win=mywin, size=0.2, pos=[0,0], sf=0, rgb=-1)

#draw the stimuli and update the window
while True: #this creates a never-ending loop
    grating.setPhase(0.05, '+')#advance phase by 0.05 of a cycle
    grating.draw()
    fixation.draw()
    mywin.flip()

    if len(event.getKeys())>0:
        break
    event.clearEvents()

#cleanup
mywin.close()
core.quit()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2.3691 	WARNING 	Monitor specification not found. Creating a temporary one...
# 5.1091 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# f:\software\2python\envs\psypy3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from IPython.display import Image
Image("paradigm1.jpg")

# %% [markdown]
# # JinBiao's Exp paradigm building
#
# The following variables including inputs and outputs should be considered:
# - the time annotation since the python window is not able to communicate with python (maybe by LCL, we can have access the data in real time, but in the begining stage, we put this idea aside). The time annotation will help us segment the signal later when processing it
# - a verbal instruction should be given out - or a computer-synthesized sound should be recorded at the begining of the paradigm

# %%
# Utils py file
# Run before start the Exp
# Author: Gansheng TAN ,19 sept 2019
def showRightArrow():
    upperLine = visual.Line(win=mywin,start=(0, 1), end=(1, 0))
    lowerLine = visual.Line(win=mywin,start=(0, -1), end=(1, 0))
    horizontalLine = visual.Line(win=mywin,start=(-2, 0), end=(1, 0))
    upperLine.draw()
    lowerLine.draw()
    horizontalLine.draw()
    mywin.flip()
    return True

def showLeftArrow():
    upperLine = visual.Line(win=mywin,start=(0, 1), end=(-1, 0))
    lowerLine = visual.Line(win=mywin,start=(0, -1), end=(-1, 0))
    horizontalLine = visual.Line(win=mywin,start=(2, 0), end=(-1, 0))
    upperLine.draw()
    lowerLine.draw()
    horizontalLine.draw()
    mywin.flip()

# %%
# ctrl+enter to start the Exp
from psychopy import visual, core, event
from psychopy import sound
import numpy as np
import pandas as pd

# consulting the following examples anad Enter path and max_times manually
max_times = 2
labels_fn = r'F:\software\1NE_NIC2\raw\motor_imagine_data\labels\2times_test.csv'

# variables setting
labels_df_ini = {'index':[0],'label':['leftOrRight']}
labels_df = pd.DataFrame(labels_df_ini)

beginTone = sound.backend_sounddevice.SoundDeviceSound(secs=1)
# flip(clearBuffer=True)[source]
# Flip the front and back buffers after drawing everything for your frame.
# (This replaces the update() method, better reflecting what is happening underneath).

# create window and begin welcoming words
mywin = visual.Window([1200,750],monitor="testMonitor", units="deg")
welcomingMessage = visual.TextStim(mywin, pos=(8, 0.0),
                                   text='Please listen to the guide from instrutor, and press keyboard=s to start the experiment')

#counter = 0


while True: #this creates a never-ending loop
    welcomingMessage.autoDraw = True  # Automatically draw every frame
    mywin.flip()
    if event.getKeys()==['s']:
        break
    event.clearEvents()
    
for i in range(max_times):
    # turn black and begin the experiment
    welcomingMessage.autoDraw = False
    mywin.flip()
    clock = core.Clock()
    while clock.getTime() < 2.0:  # Clock times are in seconds
        mywin.flip()
        if event.getKeys()==['e']:
            mywin.close()
            core.quit()
            break
        event.clearEvents()


    beginTone.play()
    while clock.getTime()<3.5:   
        cross = visual.GratingStim(win=mywin, size=2, pos=[0,0], sf=0, rgb=-1,mask='cross')
        cross.draw()
        mywin.flip()
        if event.getKeys()==['e']:
            mywin.close()
            core.quit()
            break
        event.clearEvents()


    direction = np.random.choice(a=['left','right'],p =[0.5,0.5])
    labels_df = labels_df.append({'index':i,'label':direction},ignore_index=True)
    while clock.getTime() < 6.5:
        if direction =='left':
            showLeftArrow()
            
        elif direction == 'right':
            showRightArrow()
        else:
            print('undefined direction')

        if event.getKeys()==['e']:
            mywin.close()
            core.quit()
            break
        event.clearEvents()
        
    while clock.getTime() <8:
        if event.getKeys()==['e']:
            mywin.close()
            core.quit()
            break
        mywin.flip()


#cleanup
mywin.close()
core.quit()
# Out:
# 267.1263 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.1575 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.1707 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.1906 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.2081 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.2243 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.2410 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.2581 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.2749 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.2914 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.3079 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.3255 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.3413 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.3579 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.3747 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.3917 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.4081 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.4248 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.4416 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.4586 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.4749 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.4933 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.5090 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.5248 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.5415 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.5585 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.5752 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.5925 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.6082 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.6252 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.6416 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.6581 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.6753 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.6930 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.7083 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.7250 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.7425 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.7585 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.7752 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.7919 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.8083 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.8265 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.8452 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.8611 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.8780 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.8934 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.9090 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.9256 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.9422 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.9588 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.9755 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 267.9923 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.0089 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.0254 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.0426 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.0589 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.0756 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.0926 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.1090 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.1257 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.1426 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# 268.1595 	WARNING 	Use of rgb arguments to stimuli are deprecated. Please use color and colorSpace args instead
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# f:\software\2python\envs\psypy3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# After test - data storage 
labels_df.to_csv(labels_fn)

# %% [markdown]
# ## Some works rest to be done
# - the overall loop = 50
# - give out the label = defind two functions and np.ram
# - aesthetic refinement

# %%
# Debug and test cell
import numpy as np
direction = np.random.choice(a=['left','right'],p =[0.5,0.5])
import pandas as pd
labels_df_ini = {'index':[0],'label':['leftOrRight']}
labels_df = pd.DataFrame(labels_df_ini)
labels_df
# Out:
#    index        label
# 0      0  leftOrRight

# %%
# Sound Testing
# from psychopy import sound
# mySound = sound.Sound('A')
# mySound.play(when=2)
beginTone = sound.backend_sounddevice.SoundDeviceSound(secs=1)
beginTone.play()
